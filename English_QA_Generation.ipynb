# %% [markdown]
# ## **Generating Q&As from Documents**

# %%
import re
import PyPDF2
from openai import OpenAI
from typing import List, Tuple, Dict
import logging
from pathlib import Path
import concurrent.futures
import json
from datetime import datetime
from tqdm import tqdm

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# %% [markdown]
# Process a single PDF file

# %%
def process_pdf(pdf_path: Path, chunk_size: int = 400) -> Dict:
    """
    Process a single PDF file and return its chunks and metadata.
    
    Args:
        pdf_path: Path to the PDF file
        chunk_size: Size of each text chunk
        
    Returns:
        Dictionary containing text chunks and metadata
    """
    try:
        if not pdf_path.exists():
            raise FileNotFoundError(f"PDF file not found: {pdf_path}")
            
        with pdf_path.open('rb') as pdf_file:
            pdf_reader = PyPDF2.PdfReader(pdf_file)
            text = ''
            metadata = {
                'filename': pdf_path.name,
                'pages': len(pdf_reader.pages),
                'processed_date': datetime.now().isoformat()
            }
            
            # Extract text page by page
            for i, page in enumerate(pdf_reader.pages):
                try:
                    text += page.extract_text()
                except Exception as e:
                    logger.warning(f"Failed to extract text from {pdf_path.name}, page {i}: {e}")
                    continue
            
            # Split text into chunks
            chunks = []
            current_chunk = ""
            
            sentences = re.split(r'(?<=[.!?])\s+', text)
            for sentence in sentences:
                if len(current_chunk) + len(sentence) <= chunk_size:
                    current_chunk += sentence + " "
                else:
                    chunks.append(current_chunk.strip())
                    current_chunk = sentence + " "
            
            if current_chunk:
                chunks.append(current_chunk.strip())
            
            metadata['chunk_count'] = len(chunks)
            
            return {
                'chunks': chunks,
                'metadata': metadata
            }
            
    except Exception as e:
        logger.error(f"Error processing PDF {pdf_path.name}: {e}")
        return {
            'chunks': [],
            'metadata': {
                'filename': pdf_path.name,
                'error': str(e),
                'processed_date': datetime.now().isoformat()
            }
        }

# %% [markdown]
# Function to generate Q&A pairs for multiple chunks

# %%
def generate_qa_for_chunks(chunks: List[str], pdf_name: str, client: OpenAI, model: str = "llama2:7b") -> List[Dict]:
    """
    Generate Q&A pairs for multiple chunks of text in a batch.
    
    Args:
        chunks: List of text chunks to process
        pdf_name: Name of the source PDF
        client: OpenAI client instance
        model: Name of the model to use
        
    Returns:
        List of dictionaries containing Q&A pairs and metadata for each chunk
    """
    results = []
    for chunk_index, chunk in enumerate(chunks):
        try:
            prompt = (
                "Read the following text and generate 10 question-answer pairs. "
                "Make sure questions are clear and answers are accurate and concise.\n\n"
                f"Text: {chunk}\n\n"
                "Format each pair as:\nQ: Question\nA: Answer\n. Strictly follow the format"
            )
            
            response = client.completions.create(
                model=model,
                prompt=prompt,
                max_tokens=3000,
                temperature=0.3
            )
            
            results.append({
                'content': response.choices[0].text.strip(),
                'metadata': {
                    'pdf_name': pdf_name,
                    'chunk_index': chunk_index,
                    'generated_date': datetime.now().isoformat()
                }
            })
        except Exception as e:
            logger.error(f"Error generating Q&A pairs for {pdf_name}, chunk {chunk_index}: {e}")
            results.append({
                'content': '',
                'metadata': {
                    'pdf_name': pdf_name,
                    'chunk_index': chunk_index,
                    'error': str(e),
                    'generated_date': datetime.now().isoformat()
                }
            })
    return results

# %% [markdown]
# Function to process a folder of PDFs efficiently

# %%
def process_folder(folder_path: str, output_dir: str, client: OpenAI, max_workers: int = 4) -> None:
    """
    Process all PDFs in a folder and generate Q&A pairs efficiently.
    
    Args:
        folder_path: Path to folder containing PDFs
        output_dir: Path to output directory
        client: OpenAI client instance
        max_workers: Maximum number of parallel workers
    """
    try:
        # Create output directory if it doesn't exist
        output_path = Path(output_dir)
        output_path.mkdir(parents=True, exist_ok=True)
        
        # Get all PDF files in the folder
        folder = Path(folder_path)
        pdf_files = list(folder.glob('*.pdf'))
        
        if not pdf_files:
            logger.warning(f"No PDF files found in {folder_path}")
            return
        
        logger.info(f"Found {len(pdf_files)} PDF files to process")
        
        # Process PDFs in parallel
        with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
            # Process PDFs and extract chunks
            pdf_futures = {executor.submit(process_pdf, pdf_file): pdf_file 
                         for pdf_file in pdf_files}
            
            pdf_results = {}
            for future in tqdm(concurrent.futures.as_completed(pdf_futures), 
                             total=len(pdf_files), 
                             desc="Processing PDFs"):
                pdf_file = pdf_futures[future]
                try:
                    pdf_results[pdf_file.name] = future.result()
                except Exception as e:
                    logger.error(f"Failed to process {pdf_file.name}: {e}")
            
            # Generate Q&A pairs for all chunks
            for pdf_name, result in pdf_results.items():
                chunks = result['chunks']
                if not chunks:
                    continue
                
                qa_results = generate_qa_for_chunks(chunks, pdf_name, client)
                
                # Save Q&A pairs
                qa_output_path = output_path / f"{Path(pdf_name).stem}_qa.txt"
                with qa_output_path.open('w', encoding='utf-8') as f:
                    for qa in sorted(qa_results, key=lambda x: x['metadata']['chunk_index']):
                        f.write(qa['content'] + '\n\n')
                
                # Save metadata
                metadata_output_path = output_path / f"{Path(pdf_name).stem}_metadata.json"
                metadata = {
                    'pdf_metadata': result['metadata'],
                    'qa_metadata': [qa['metadata'] for qa in qa_results]
                }
                with metadata_output_path.open('w', encoding='utf-8') as f:
                    json.dump(metadata, f, indent=2)
        
        logger.info(f"Successfully processed {len(pdf_files)} PDFs. Results saved in {output_dir}")
        
    except Exception as e:
        logger.error(f"Error processing folder: {e}")
        raise

# %% [markdown]
# Function to extract Q&A pairs from a file

# %%
def extract_qna_from_file(file_path: str) -> Tuple[List[str], List[str]]:
    """
    Extract questions and answers from a generated Q&A file.
    
    Args:
        file_path: Path to the Q&A file
        
    Returns:
        Tuple of (questions list, answers list)
    """
    try:
        input_path = Path(file_path)
        if not input_path.exists():
            raise FileNotFoundError(f"Input file not found: {file_path}")
            
        with input_path.open('r', encoding='utf-8') as file:
            content = file.read()
            
        pattern = r'Q:\s*(.*?)\s*\nA:\s*(.*?)(?=\s*(?:Q:|$))'
        qna_pairs = re.findall(pattern, content, re.DOTALL)
        
        questions = [q.strip() for q, _ in qna_pairs]
        answers = [a.strip() for _, a in qna_pairs]
        
        logger.info(f"Successfully extracted {len(questions)} Q&A pairs from {file_path}")
        return questions, answers
        
    except Exception as e:
        logger.error(f"Error extracting Q&A pairs from {file_path}: {e}")
        raise

# %% [markdown]
#  Main script

# %%
if __name__ == "__main__":
    # Configuration
    pdf_folder = "pdfs"  # Folder containing PDFs
    output_folder = "qa_output"  # Folder for output files
    max_workers = 4  # Number of parallel workers

    # Initialize the OpenAI client
    client = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

    # Process all PDFs in the folder
    process_folder(pdf_folder, output_folder, client, max_workers)

    # Optionally, extract and display Q&As for a specific file
    qa_files = list(Path(output_folder).glob('*_qa.txt'))
    if qa_files:
        sample_file = qa_files[0]
        print(f"\nSample Q&As from {sample_file.name}:")
        questions, answers = extract_qna_from_file(sample_file)
        for i, (q, a) in enumerate(zip(questions, answers), 1):
            print(f"\nQ{i}: {q}")
            print(f"A{i}: {a}")
# Out:
# 2025-01-09 18:22:20,348 - INFO - Found 18 PDF files to process
# Processing PDFs: 100%|██████████| 18/18 [00:00<00:00, 50.92it/s]
# 2025-01-09 18:22:35,593 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:22:48,272 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:23:00,579 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:23:11,367 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:23:19,987 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:23:31,656 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:23:42,437 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:23:51,696 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:23:59,439 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:24:08,850 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:24:19,514 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:24:29,763 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:24:38,330 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:24:47,322 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:24:58,468 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:25:08,870 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:25:19,613 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:25:30,525 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:25:42,929 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:25:52,578 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:26:02,635 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:26:13,331 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:26:23,077 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:26:32,964 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:26:40,288 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:26:51,589 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:26:59,044 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:27:08,923 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:27:19,381 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:27:31,742 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:27:42,305 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:27:54,473 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:28:04,682 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:28:16,081 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:28:24,820 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:28:36,527 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:28:51,516 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:29:01,864 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:29:13,565 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:29:26,953 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:29:40,637 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:29:54,155 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:30:08,222 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:30:21,146 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:30:31,257 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:30:42,393 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:30:55,762 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:31:08,000 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:31:17,012 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:31:27,384 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:31:38,434 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:31:48,748 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:31:58,520 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:32:05,895 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:32:20,367 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:32:32,489 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:32:43,831 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:32:54,982 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:33:04,423 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:33:18,824 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:33:31,555 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:33:44,280 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:33:55,160 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:34:07,961 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:34:20,473 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:34:33,594 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:34:42,070 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:34:53,191 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:35:00,880 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:35:11,076 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:35:22,420 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:35:31,717 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:35:43,440 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:35:55,881 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:36:03,523 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:36:12,904 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:36:23,829 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:36:34,727 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:36:43,239 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:36:53,884 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:37:02,236 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:37:10,909 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:37:19,203 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:37:30,966 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:37:43,263 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:37:53,293 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:38:07,531 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:38:24,096 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:38:38,257 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:38:49,023 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:39:02,122 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:39:11,503 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:39:21,697 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:39:30,068 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:39:41,557 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:39:49,292 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:40:05,167 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:40:15,223 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:40:24,600 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:40:36,524 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:40:48,178 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:40:58,734 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:41:07,014 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:41:15,096 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:41:24,828 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:41:38,315 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:41:48,813 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:41:58,272 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:42:10,333 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:42:23,872 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:42:36,475 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:42:47,959 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:42:55,787 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:43:06,764 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:43:15,753 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:43:23,332 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:43:34,017 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:43:46,563 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:43:54,978 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:44:06,901 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:44:16,143 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:44:26,932 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:44:35,452 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:44:47,609 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:44:57,344 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:45:08,492 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:45:15,991 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:45:26,999 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:45:36,912 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:45:49,232 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:45:58,231 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:46:07,614 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:46:15,993 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:46:23,439 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:46:34,354 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:46:44,554 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:46:56,596 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:47:11,156 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:47:23,137 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:47:34,897 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:47:42,850 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:47:57,311 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:48:08,474 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:48:19,234 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:48:31,006 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:48:44,687 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:48:57,004 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:49:07,296 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:49:19,902 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:49:33,695 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:49:45,007 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:49:58,971 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:50:10,448 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:50:20,365 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:50:26,704 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:50:35,347 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:50:46,133 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:50:55,426 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:51:04,576 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:51:14,473 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:51:24,248 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:51:32,542 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:51:41,154 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:51:49,891 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:51:59,905 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:52:09,001 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:52:17,356 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:52:26,759 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:52:36,349 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:52:46,745 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:52:57,888 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:53:11,230 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:53:23,179 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:53:33,068 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:53:43,124 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:53:51,348 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:53:59,978 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:54:10,171 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:54:17,956 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:54:26,500 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:54:38,939 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:54:49,385 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:55:00,641 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:55:14,803 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:55:26,807 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:55:36,684 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:55:47,412 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:55:55,795 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:56:02,788 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:56:14,342 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:56:23,990 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:56:32,043 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:56:40,704 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:56:49,278 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:56:57,284 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:57:04,249 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:57:13,000 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:57:20,299 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:57:30,368 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:57:38,444 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:57:46,182 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:57:57,519 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:58:06,310 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:58:15,601 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:58:26,976 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:58:40,098 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:58:46,431 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:58:55,426 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:59:02,736 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:59:10,565 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:59:19,168 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:59:29,837 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:59:40,211 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:59:48,341 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 18:59:56,714 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:00:05,874 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:00:14,632 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:00:23,322 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:00:36,077 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:00:45,453 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:00:53,629 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:01:01,711 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:01:13,104 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:01:20,479 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:01:33,341 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:01:44,635 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:01:57,243 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:02:07,283 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:02:20,553 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:02:28,084 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:02:40,032 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:02:51,482 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:02:59,959 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:03:11,028 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:03:18,815 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:03:30,343 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:03:39,601 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:03:49,115 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:04:01,518 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:04:09,801 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:04:19,970 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:04:30,238 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:04:40,844 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:04:49,625 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:05:01,084 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:05:09,068 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:05:18,812 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:05:27,435 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:05:34,873 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:05:45,048 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:05:54,344 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:06:03,190 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:06:15,186 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:06:24,848 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:06:36,927 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:06:44,322 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:06:52,598 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:07:01,472 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:07:09,924 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:07:22,425 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:07:32,792 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:07:44,168 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:07:56,752 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:08:06,534 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:08:15,853 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:08:24,453 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:08:31,444 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:08:41,636 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:08:50,678 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:09:04,446 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:09:14,571 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:09:25,146 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:09:37,630 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:09:44,828 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:09:53,392 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:10:01,083 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:10:09,203 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:10:20,854 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:10:32,332 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:10:38,658 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:10:50,988 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:11:04,067 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:11:10,770 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:11:24,113 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:11:33,468 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:11:42,718 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:11:54,929 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:12:06,796 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:12:17,350 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:12:25,101 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:12:36,826 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:12:47,269 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:13:00,678 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:13:13,107 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:13:24,159 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:13:36,582 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:13:46,676 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:13:55,891 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:14:06,157 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:14:15,288 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:14:28,184 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:14:39,706 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:14:49,942 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:14:58,747 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:15:08,625 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:15:19,586 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:15:26,653 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:15:35,168 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:15:43,358 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:15:56,489 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:16:06,512 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:16:13,857 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:16:23,845 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:16:32,285 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:16:41,591 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:16:52,047 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:17:03,588 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:17:11,717 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:17:20,708 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:17:30,748 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:17:43,472 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:17:54,428 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:18:04,826 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:18:16,415 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:18:28,700 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:18:36,198 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:18:44,652 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:18:51,309 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:18:58,283 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:19:05,686 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:19:14,243 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:19:22,693 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:19:33,431 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:19:44,075 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:19:53,585 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:20:00,150 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:20:13,839 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:20:24,974 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:20:32,154 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:20:44,755 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:20:54,680 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:21:04,461 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:21:19,703 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:21:26,965 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:21:37,970 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:21:46,697 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:21:55,433 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:22:04,546 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:22:17,751 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:22:28,182 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:22:38,037 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:22:49,576 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:23:01,818 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:23:12,995 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:23:24,780 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:23:35,254 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:23:45,645 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:23:56,755 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:24:08,647 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:24:18,903 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:24:30,292 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:24:41,421 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:24:52,356 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:25:00,035 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:25:18,427 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:25:33,576 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:25:51,068 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:26:07,700 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:26:18,248 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:26:25,205 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:26:42,331 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:26:55,005 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:27:06,471 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:27:19,572 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:27:32,814 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:27:45,601 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:27:54,833 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:28:06,619 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:28:16,538 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:28:25,446 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:28:35,169 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:28:44,727 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:28:56,904 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:29:07,307 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:29:17,072 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:29:30,548 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:29:37,826 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:29:51,402 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:30:02,373 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:30:13,973 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:30:25,324 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:30:36,148 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:30:51,512 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:31:04,442 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:31:16,932 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:31:26,250 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:31:45,649 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:31:56,667 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:32:07,042 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:32:19,017 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:32:31,715 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:32:40,993 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:32:51,592 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:33:01,877 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:33:11,177 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:33:22,707 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:33:35,642 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:33:45,824 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:33:57,038 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:34:07,936 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:34:19,084 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:34:34,743 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:34:47,396 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:35:01,216 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:35:10,836 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:35:20,683 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:35:33,237 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:35:50,500 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:36:00,018 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:36:09,059 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:36:23,263 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:36:35,965 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:36:44,341 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:36:55,811 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:37:09,175 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:37:17,574 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:37:30,356 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:37:41,100 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:37:55,566 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:38:08,552 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:38:19,824 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:38:29,117 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:38:38,158 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:38:51,382 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:39:04,018 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:39:16,829 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:39:29,059 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:39:42,891 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:39:58,364 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:40:13,842 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:40:27,647 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:40:39,352 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 19:40:54,267 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# ...
# 2025-01-09 20:22:11,858 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:22:26,677 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:22:41,639 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:22:51,906 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:23:06,395 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:23:21,314 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:23:30,555 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:23:39,771 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:23:53,862 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:24:08,034 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:24:14,890 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:24:26,108 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:24:40,600 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:24:53,929 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:25:08,336 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:25:20,857 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:25:35,585 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:25:49,462 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:26:06,966 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:26:23,872 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:26:34,145 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:26:49,186 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:27:02,641 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:27:16,201 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:27:28,180 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:27:41,243 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:27:58,751 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:28:14,194 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:28:24,919 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:28:35,307 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:28:49,035 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:29:03,561 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:29:16,791 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:29:31,784 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:29:44,246 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:29:58,995 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:30:11,810 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# 2025-01-09 20:30:26,318 - INFO - HTTP Request: POST http://localhost:11434/v1/completions "HTTP/1.1 200 OK"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 11
#       8 client = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
#      10 # Process all PDFs in the folder
# ---> 11 process_folder(pdf_folder, output_folder, client, max_workers)
#      13 # Optionally, extract and display Q&As for a specific file
#      14 qa_files = list(Path(output_folder).glob('*_qa.txt'))
#
# Cell In[5], line 48, in process_folder(folder_path, output_dir, client, max_workers)
#      45 if not chunks:
#      46     continue
# ---> 48 qa_results = generate_qa_for_chunks(chunks, pdf_name, client)
#      50 # Save Q&A pairs
#      51 qa_output_path = output_path / f"{Path(pdf_name).stem}_qa.txt"
#
# Cell In[4], line 24, in generate_qa_for_chunks(chunks, pdf_name, client, model)
#      16 try:
#      17     prompt = (
#      18         "Read the following text and generate 10 question-answer pairs. "
#      19         "Make sure questions are clear and answers are accurate and concise.\n\n"
#      20         f"Text: {chunk}\n\n"
#      21         "Format each pair as:\nQ: Question\nA: Answer\n. Strictly follow the format"
#      22     )
# ---> 24     response = client.completions.create(
#      25         model=model,
#      26         prompt=prompt,
#      27         max_tokens=3000,
#      28         temperature=0.3
#      29     )
#      31     results.append({
#      32         'content': response.choices[0].text.strip(),
#      33         'metadata': {
#    (...)
#      37         }
#      38     })
#      39 except Exception as e:
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\openai\resources\completions.py:539, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     510 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     511 def create(
#     512     self,
#    (...)
#     537     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     538 ) -> Completion | Stream[Completion]:
# --> 539     return self._post(
#     540         "/completions",
#     541         body=maybe_transform(
#     542             {
#     543                 "model": model,
#     544                 "prompt": prompt,
#     545                 "best_of": best_of,
#     546                 "echo": echo,
#     547                 "frequency_penalty": frequency_penalty,
#     548                 "logit_bias": logit_bias,
#     549                 "logprobs": logprobs,
#     550                 "max_tokens": max_tokens,
#     551                 "n": n,
#     552                 "presence_penalty": presence_penalty,
#     553                 "seed": seed,
#     554                 "stop": stop,
#     555                 "stream": stream,
#     556                 "stream_options": stream_options,
#     557                 "suffix": suffix,
#     558                 "temperature": temperature,
#     559                 "top_p": top_p,
#     560                 "user": user,
#     561             },
#     562             completion_create_params.CompletionCreateParams,
#     563         ),
#     564         options=make_request_options(
#     565             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     566         ),
#     567         cast_to=Completion,
#     568         stream=stream or False,
#     569         stream_cls=Stream[Completion],
#     570     )
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\openai\_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\openai\_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\openai\_base_client.py:996, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     993 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     995 try:
# --> 996     response = self._client.send(
#     997         request,
#     998         stream=stream or self._should_stream_response_body(request=request),
#     999         **kwargs,
#    1000     )
#    1001 except httpx.TimeoutException as err:
#    1002     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\23030014\Thesis Research\Project Code\env_name\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
import os

def reformat_qa_file(input_file, output_file):
    """
    Reformat Q&A text file to a cleaner format for easier reading and processing.
    Handles both `**Q:` and `**Q**:` formats. Stray lines are removed.

    Args:
        input_file (str): Path to the input text file.
        output_file (str): Path to save the reformatted text file.
    """
    with open(input_file, 'r') as file:
        lines = file.readlines()
    
    reformatted_lines = []
    current_question = ""
    current_answer = ""
    
    for line in lines:
        line = line.strip()
        if line.startswith("**Q:") or line.startswith("**Q**:"):
            # If we already have a Q and A in progress, append them first
            if current_question:
                reformatted_lines.append(f"Q: {current_question}\nA: {current_answer}\n")
            # Start a new Q
            current_question = line.replace("**Q:", "").replace("**Q**:", "").replace("**", "").strip()
            current_answer = ""
        elif line.startswith("**A:") or line.startswith("**A**:"):
            # Capture the answer portion
            current_answer = line.replace("**A:", "").replace("**A**:", "").replace("**", "").strip()
        else:
            # Ignore stray lines
            continue

    # If there's one last Q&A after the loop finishes, append it
    if current_question:
        reformatted_lines.append(f"Q: {current_question}\nA: {current_answer}\n")
    
    with open(output_file, 'w') as file:
        file.writelines(reformatted_lines)


def process_all_txt_files_in_folder(input_folder, output_folder):
    """
    Processes all .txt files in the input folder, reformats them, and saves to the output folder.

    Args:
        input_folder (str): Path to the folder containing input .txt files.
        output_folder (str): Path to the folder to save reformatted .txt files.
    """
    # Ensure output folder exists
    os.makedirs(output_folder, exist_ok=True)
    
    # Iterate over all .txt files in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.endswith(".txt"):
            input_file_path = os.path.join(input_folder, file_name)
            output_file_path = os.path.join(output_folder, file_name)
            
            # Reformat the Q&A file
            reformat_qa_file(input_file_path, output_file_path)
            print(f"Processed: {file_name} -> {output_file_path}")

# %%
# Example usage:
input_folder_path = 'qa_output'       # Replace with your actual folder containing .txt Q&A files
output_folder_path = 'refined_q&as'   # The folder where you want the cleaned files to go

process_all_txt_files_in_folder(input_folder_path, output_folder_path)
print("Processing completed.")
# Out:
# Processed: 2008_Summer_Olympics_torch_relay_qa.txt -> refined_q&as\2008_Summer_Olympics_torch_relay_qa.txt
# Processed: Adult_contemporary_music_qa.txt -> refined_q&as\Adult_contemporary_music_qa.txt
# Processed: Affirmative_action_in_the_United_States_qa.txt -> refined_q&as\Affirmative_action_in_the_United_States_qa.txt
# Processed: Aircraft_carrier_qa.txt -> refined_q&as\Aircraft_carrier_qa.txt
# Processed: Airport_qa.txt -> refined_q&as\Airport_qa.txt
# Processing completed.
